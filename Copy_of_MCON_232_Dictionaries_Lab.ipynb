# %% [markdown]
# <a href="https://colab.research.google.com/github/mlevy34/mcon232_module1_Michellelevy/blob/main/Copy_of_MCON_232_Dictionaries_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Your Name Michelle Levy
#
# ## Topic : Dictionaries Lab

# %%
my_dict = {
    "Name" : "Michelle",
    "Age" : "18",
    "Gender" : "Female"
}
my_dict["Eye color"] = "brown"
print(my_dict)
print(my_dict["Name"])
print(my_dict["Eye color"])
try:
  print(my_dict["hair color"])
except KeyError as ke:
  print("key not found", ke)
# Out:
# {'Name': 'Michelle', 'Age': '18', 'Gender': 'Female', 'Eye color': 'brown'}
# Michelle
# brown
# key not found 'hair color'

# %%
print("Age" in my_dict)
print("18" not in my_dict)
# Out:
# True
# True

# %%
my_dict2 = {}
my_dict2["cat"] = "polly"
print(my_dict2)
print(my_dict2)
# Out:
# {'cat': 'polly'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-807382310.py in <cell line: 0>()
#       3 print(my_dict2)
#       4 del(my_dict2)
# ----> 5 print(my_dict2)
#
# NameError: name 'my_dict2' is not defined

# %%
animal = my_dict["Name"]
print(animal)
print(len(my_dict))
# Out:
# Michelle
# 4

# %%
for k in my_dict:
  print(f"key: {k} value: {my_dict[k]}")
for v in my_dict.values():
  print(f"our value is {v}")
for k, v in my_dict.items():
  print(f"key: {k} value{v}")
# Out:
# key: Name value: Michelle
# key: Age value: 18
# key: Gender value: Female
# key: Eye color value: brown
# our value is Michelle
# our value is 18
# our value is Female
# our value is brown
# key: Name valueMichelle
# key: Age value18
# key: Gender valueFemale
# key: Eye color valuebrown

# %%
for v in my_dict.values():
  print(f"our value is {v}")
# Out:
# our value is Michelle
# our value is 18
# our value is Female
# our value is brown

# %%
import copy
my_dict = {
    "Name" : "Michelle",
    "Age" : "18",
    "Gender" : "Female"
}
my_dict.get("Name")
my_dict.pop("Age")
print(my_dict)
my_dict3 = {
    "Color" : "blue",
    "Food" : "cake",
    "1+1" : "2"
}
my_dict4 = my_dict | my_dict3
print(my_dict4)
my_dict3 |= my_dict
print(my_dict3)
my_dict5 = my_dict3.copy()
print(my_dict5)
# Out:
# {'Name': 'Michelle', 'Gender': 'Female'}
# {'Name': 'Michelle', 'Gender': 'Female', 'Color': 'blue', 'Food': 'cake', '1+1': '2'}
# {'Color': 'blue', 'Food': 'cake', '1+1': '2', 'Name': 'Michelle', 'Gender': 'Female'}
# {'Color': 'blue', 'Food': 'cake', '1+1': '2', 'Name': 'Michelle', 'Gender': 'Female'}

# %%
k, v = ("name", my_dict["Name"])
print(k, v)

for k,v in my_dict3.items():
  if v == "cake":
    print(f"key: {k}, value: {v}")
# Out:
# name Michelle
# key: Food, value: cake

# %%
from os import O_NDELAY
print(list(my_dict.keys()))
dict_nums = {
       1 : ["one", "won"],
       2 : "two",
       3 : "three",
       4 : "four"
  }
dict_even = {key : value for key, value in dict_nums.items() if key % 2 == 0}
print(dict_even)
print(dict_nums[1][1])
# Out:
# ['Name', 'Gender']
# {2: 'two', 4: 'four'}
# won

# %%
my_dict6 = {key : value for key,value in my_dict3.items()}
print(my_dict6)
# Out:
# {'Color': 'blue', 'Food': 'cake', '1+1': '2', 'Name': 'Michelle', 'Gender': 'Female'}

# %%
my_dict = {
    "123" : "456",
    "567" : {9 : "hi"}
}
print(my_dict["567"][9])
# Out:
# hi
